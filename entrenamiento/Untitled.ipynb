# %%
import pandas as pd
from sklearn.model_selection import train_test_split
import os

# %%
separator = os.path.sep
path_act = os.path.dirname(os.path.abspath("__file__"))
dir = separator.join(path_act.split(separator)[:-1])

# %%
def generated_tts():
    df = pd.read_csv(f'{dir}/dataset.csv')
    df.columns = [i for i in range(df.shape[1])]
    df = df.rename(columns={63: 'Output'})
    X = df.iloc[:, :-1]
    Y = df.iloc[:, -1]
    return train_test_split(X, Y, test_size=0.2)

# %%
def path_act():
    separator = os.path.sep
    path_act = os.path.dirname(os.path.abspath(__file__))
    dir = separator.join(path_act.split(separator)[:-1])
    return str(dir)

# %%
X_train, X_test, y_train, y_test = generated_tts()

# %%
X_train
# Out:
#            0         1             2         3         4         5         6   \
# 404  0.000000  0.000000  0.000000e+00  0.000000  0.000000  0.000000  0.000000
# 522  0.000000  0.000000  0.000000e+00  0.000000  0.000000  0.000000  0.000000
# 35   0.713162  0.860814  6.053464e-07  0.646780  0.836007 -0.038507  0.595472
# 52   0.657982  0.916362  6.834277e-07  0.574043  0.893761 -0.056223  0.506374
# 355  0.000000  0.000000  0.000000e+00  0.000000  0.000000  0.000000  0.000000
# ..        ...       ...           ...       ...       ...       ...       ...
# 48   0.671450  0.833098  7.674398e-07  0.603412  0.820028 -0.047792  0.548331
# 178  0.000000  0.000000  0.000000e+00  0.000000  0.000000  0.000000  0.000000
# 39   0.000000  0.000000  0.000000e+00  0.000000  0.000000  0.000000  0.000000
# 365  0.000000  0.000000  0.000000e+00  0.000000  0.000000  0.000000  0.000000
# 56   0.000000  0.000000  0.000000e+00  0.000000  0.000000  0.000000  0.000000
#
#            7         8         9   ...        53        54        55  \
# 404  0.000000  0.000000  0.000000  ...  0.000000  0.000000  0.000000
# 522  0.000000  0.000000  0.000000  ...  0.000000  0.000000  0.000000
# 35   0.770304 -0.062162  0.555563  ... -0.065634  0.786649  0.590656
# 52   0.824289 -0.098501  0.454664  ... -0.096795  0.763143  0.598820
# 355  0.000000  0.000000  0.000000  ...  0.000000  0.000000  0.000000
# ..        ...       ...       ...  ...       ...       ...       ...
# 48   0.764205 -0.081467  0.507703  ... -0.079654  0.754771  0.568916
# 178  0.000000  0.000000  0.000000  ...  0.000000  0.000000  0.000000
# 39   0.000000  0.000000  0.000000  ...  0.000000  0.000000  0.000000
# 365  0.000000  0.000000  0.000000  ...  0.000000  0.000000  0.000000
# 56   0.000000  0.000000  0.000000  ...  0.000000  0.000000  0.000000
#
#            56        57        58        59        60        61        62
# 404  0.000000  0.000000  0.000000  0.000000  0.000000  0.000000  0.000000
# 522  0.000000  0.000000  0.000000  0.000000  0.000000  0.000000  0.000000
# 35  -0.093617  0.797972  0.535824 -0.104917  0.806680  0.485309 -0.111229
# 52  -0.128146  0.775941  0.526414 -0.142656  0.788546  0.465156 -0.150011
# 355  0.000000  0.000000  0.000000  0.000000  0.000000  0.000000  0.000000
# ..        ...       ...       ...       ...       ...       ...       ...
# 48  -0.107709  0.765642  0.511992 -0.119434  0.776168  0.461175 -0.125075
# 178  0.000000  0.000000  0.000000  0.000000  0.000000  0.000000  0.000000
# 39   0.000000  0.000000  0.000000  0.000000  0.000000  0.000000  0.000000
# 365  0.000000  0.000000  0.000000  0.000000  0.000000  0.000000  0.000000
# 56   0.000000  0.000000  0.000000  0.000000  0.000000  0.000000  0.000000
#
# [559 rows x 63 columns]
