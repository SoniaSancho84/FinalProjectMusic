# %%
import pandas as pd
from sklearn.model_selection import train_test_split
import os

# %%
separator = os.path.sep
path_act = os.path.dirname(os.path.abspath("__file__"))
dir = separator.join(path_act.split(separator)[:-1])

# %%
def generated_tts():
    df = pd.read_csv(f'{dir}/dataset.csv')
    df.columns = [i for i in range(df.shape[1])]
    df = df.rename(columns={63: 'Output'})
    X = df.iloc[:, :-1]
    Y = df.iloc[:, -1]
    return train_test_split(X, Y, test_size=0.2)

# %%
def path_act():
    separator = os.path.sep
    path_act = os.path.dirname(os.path.abspath(__file__))
    dir = separator.join(path_act.split(separator)[:-1])
    return str(dir)

# %%
X_train, X_test, y_train, y_test = generated_tts()

# %%
X_train
# Out:
#            0         1             2         3         4         5         6   \
# 372  0.000000  0.000000  0.000000e+00  0.000000  0.000000  0.000000  0.000000
# 631  0.000000  0.000000  0.000000e+00  0.000000  0.000000  0.000000  0.000000
# 142  0.319284  0.718131  3.941485e-07  0.258603  0.701104 -0.020856  0.212099
# 654  0.748775  0.777134 -1.166604e-07  0.706177  0.744642 -0.027520  0.661395
# 583  0.543002  0.895570  5.683938e-07  0.493833  0.852369 -0.024814  0.468829
# ..        ...       ...           ...       ...       ...       ...       ...
# 572  0.000000  0.000000  0.000000e+00  0.000000  0.000000  0.000000  0.000000
# 347  0.000000  0.000000  0.000000e+00  0.000000  0.000000  0.000000  0.000000
# 707  0.906675  0.956400  3.541803e-07  0.859453  0.916207 -0.034737  0.843376
# 571  0.813409  0.950327  4.873054e-07  0.762438  0.914668 -0.046611  0.745745
# 452  0.826469  0.766062  3.634002e-07  0.785478  0.716522 -0.025327  0.773748
#
#            7         8         9   ...        53        54        55  \
# 372  0.000000  0.000000  0.000000  ...  0.000000  0.000000  0.000000
# 631  0.000000  0.000000  0.000000  ...  0.000000  0.000000  0.000000
# 142  0.648281 -0.033976  0.177114  ... -0.049254  0.343166  0.454221
# 654  0.683846 -0.041653  0.619688  ... -0.035472  0.798699  0.623748
# 583  0.785029 -0.041148  0.483725  ... -0.056065  0.582817  0.693358
# ..        ...       ...       ...  ...       ...       ...       ...
# 572  0.000000  0.000000  0.000000  ...  0.000000  0.000000  0.000000
# 347  0.000000  0.000000  0.000000  ...  0.000000  0.000000  0.000000
# 707  0.847654 -0.052313  0.889194  ... -0.040578  0.979247  0.704531
# 571  0.845085 -0.069307  0.792509  ... -0.051003  0.895805  0.731647
# 452  0.626809 -0.027156  0.820378  ... -0.020186  0.873840  0.542833
#
#            56        57        58        59        60        61        62
# 372  0.000000  0.000000  0.000000  0.000000  0.000000  0.000000  0.000000
# 631  0.000000  0.000000  0.000000  0.000000  0.000000  0.000000  0.000000
# 142 -0.071050  0.350450  0.400948 -0.082093  0.355999  0.353269 -0.088915
# 654 -0.056659  0.781266  0.664877 -0.047572  0.775124  0.672620 -0.035392
# 583 -0.083230  0.561051  0.712554 -0.086704  0.547094  0.731177 -0.084822
# ..        ...       ...       ...       ...       ...       ...       ...
# 572  0.000000  0.000000  0.000000  0.000000  0.000000  0.000000  0.000000
# 347  0.000000  0.000000  0.000000  0.000000  0.000000  0.000000  0.000000
# 707 -0.060273  0.984977  0.657227 -0.071086  0.987564  0.615389 -0.078052
# 571 -0.094710  0.894328  0.760359 -0.104889  0.889080  0.790200 -0.103300
# 452 -0.047444  0.862203  0.580760 -0.056061  0.856517  0.619738 -0.060240
#
# [639 rows x 63 columns]
